# %%
import src as lmbh
# from src.simulation.params import Simulation

# %%
n = 10
params = lmbh.simulation.params
sim = params.Simulation(
    graph = lmbh.simulation.graphs.GraphGenerators.complete_graph_of_allies(n),
    prior_params = params.UniformRandomPriorParams(n=n, partisans=[-1]),
    coin_params = params.RandomCoinParams(),
)

# %%
sim.analyse.show_graph()

# %%
sim.analyse.plot_all_mean()

# %%
sim.analyse.plot_asymptotic_learning_steps()

# %%
sim.analyse.plot_distr(-1)
